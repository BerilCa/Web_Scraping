# %%
import pandas as pd

df = pd.read_csv("scraped_data.csv")
df.head()
# Out:
#                                                store  store code  \
# 0                                          Not found   Not found
# 1  Pradhan Mantri Bhartiya Janaushadhi Kendra (PM...  PMBJK00863
# 2  Pradhan Mantri Bhartiya Janaushadhi Kendra (PM...  PMBJK02474
# 3  Pradhan Mantri Bhartiya Janaushadhi Kendra (PM...  PMBJK02476
# 4  Pradhan Mantri Bhartiya Janaushadhi Kendra (PM...  PMBJK02477
#
#                                              address          state  \
# 0                                          Not found      Not found
# 1  Mm-1/70 Sector- A, Sbi Colony Sitapur Road Yoj...  Uttar Pradesh
# 2  Shop No-Lgf 10, B-1833/1, Indira Nagar, LuckNo...  Uttar Pradesh
# 3  Jan Aushadhi Medical Store-CSC, 3/70, Sector-G...  Uttar Pradesh
# 4  D-4/240, Near Shankar Chauraha, Vishal Khand 4...  Uttar Pradesh
#
#     pin code   district             contact person contact detail       status
# 0  Not found  Not found                  Not found      Not found    Not found
# ...

# %%
df.tail()
# Out:
#           store store code    address      state   pin code   district  \
# 9587  Not found  Not found  Not found  Not found  Not found  Not found
# 9588  Not found  Not found  Not found  Not found  Not found  Not found
# 9589  Not found  Not found  Not found  Not found  Not found  Not found
# 9590  Not found  Not found  Not found  Not found  Not found  Not found
# 9591  Not found  Not found  Not found  Not found  Not found  Not found
#
#      contact person contact detail     status
# 9587      Not found      Not found  Not found
# 9588      Not found      Not found  Not found
# 9589      Not found      Not found  Not found
# 9590      Not found      Not found  Not found
# 9591      Not found      Not found  Not found
